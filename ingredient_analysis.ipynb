# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
a = pd.read_csv("/content/drive/MyDrive/ingredient_analyze/ingredient_info.csv", encoding='cp949')

# %%
a
# Out:
#                      식품코드                       식품명 데이터구분코드   데이터구분명  식품기원코드  \
# 0     R209-027074601-0000  소고기_한우(1+등급)_등심(윗등심살)_생것       R  원재료성 식품       2
# 1     R209-027074701-0000   소고기_한우(1+등급)_사태(뒷사태)_생것       R  원재료성 식품       2
# 2     R209-027074801-0000  소고기_한우(1+등급)_사태(뭉치사태)_생것       R  원재료성 식품       2
# 3     R209-027074901-0000   소고기_한우(1+등급)_사태(상박살)_생것       R  원재료성 식품       2
# 4     R209-027075001-0000  소고기_한우(1+등급)_사태(아롱사태)_생것       R  원재료성 식품       2
# ...                   ...                       ...     ...      ...     ...
# 3603  R211-715154001-0008        게류_붉은대게_육_생것_대표_8월       R  원재료성 식품       2
# 3604  R211-715154301-0009        게류_붉은대게_알_생것_대표_9월       R  원재료성 식품       2
# 3605  R220-027006001-0000                귀뚜라미_성충_생것       R  원재료성 식품       2
# 3606  R101-001020101-0000              귀리_쌀귀리_도정_생것       R  원재료성 식품       1
# 3607  R101-001010101-0000              귀리_겉귀리_도정_생것       R  원재료성 식품       1
#
# ...

# %%
selected_columns = a.iloc[:, [7,8,9]]

# %%
selected_columns
# Out:
#             식품대분류명  대표식품코드 대표식품명
# 0               육류    9027   소고기
# 1               육류    9027   소고기
# 2               육류    9027   소고기
# 3               육류    9027   소고기
# 4               육류    9027   소고기
# ...            ...     ...   ...
# 3603  어패류 및 기타 수산물   11715    게류
# 3604  어패류 및 기타 수산물   11715    게류
# 3605            기타   20027  귀뚜라미
# 3606            곡류    1001    귀리
# 3607            곡류    1001    귀리
#
# [3608 rows x 3 columns]

# %%
sorted_columns = selected_columns.sort_values(by='식품대분류명')

# %%
pd.set_option('display.max_rows', 100)  # 최대 100개의 행까지만 보여주기
pd.set_option('display.max_columns', None)  # 모든 열 보여주기

# %%
sorted_columns
# Out:
#         식품대분류명  대표식품코드 대표식품명
# 1726  감자 및 전분류    2010  돼지감자
# 1748  감자 및 전분류    2001    감자
# 1749  감자 및 전분류    2001    감자
# 1750  감자 및 전분류    2001    감자
# 1751  감자 및 전분류    2001    감자
# ...        ...     ...   ...
# 3006       해조류   12827  모자반류
# 3005       해조류   12827  모자반류
# 3004       해조류   12827  모자반류
# 3002       해조류   12825   매생이
# 2162       해조류   12819  다시마류
#
# [3608 rows x 3 columns]

# %% [markdown]
# 현재 "식품대분류명"을 기준으로 정렬 완료 되었다.

# %%
sorted_columns_unique = sorted_columns.drop_duplicates() #"식품대분류명", "대표식품코드", "대표식품명" 열을 기준으로 중복이 제거된 상태로 출력

# %%
sorted_columns_unique
# Out:
#         식품대분류명  대표식품코드     대표식품명
# 1726  감자 및 전분류    2010      돼지감자
# 1748  감자 및 전분류    2001        감자
# 678   감자 및 전분류    2006       고구마
# 663   감자 및 전분류    2005      으깬감자
# 1701  감자 및 전분류    2009  곤약(구약나물)
# ...        ...     ...       ...
# 2994       해조류   12815     꼬시래기류
# 2985       해조류   12811      갈래곰보
# 3001       해조류   12823       뜸부기
# 3020       해조류   12839        순채
# 3019       해조류   12837        석묵
#
# [716 rows x 3 columns]

# %%
selected_columns_2 = sorted_columns_unique.iloc[:, [0,2]]

# %%
# 행 번호 재설정
selected_columns_2.reset_index(drop=True, inplace=True)

# %%
selected_columns_2
# Out:
#        식품대분류명     대표식품명
# 0    감자 및 전분류      돼지감자
# 1    감자 및 전분류        감자
# 2    감자 및 전분류       고구마
# 3    감자 및 전분류      으깬감자
# 4    감자 및 전분류  곤약(구약나물)
# ..        ...       ...
# 711       해조류     꼬시래기류
# 712       해조류      갈래곰보
# 713       해조류       뜸부기
# 714       해조류        순채
# 715       해조류        석묵
#
# [716 rows x 2 columns]

# %%
selected_columns_2.to_csv('analyzed_ingredient.csv')
